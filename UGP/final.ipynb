# %%
import torch
import torch.nn as nn
import torch.optim as optim

from models.model import base_Model          # <-- this was missing
from config_files.Epilepsy_Configs import Config as Configs

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
configs = Configs()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import torch
#       2 import torch.nn as nn
#       3 import torch.optim as optim
#
# File ~/Venvs/Aditya/lib/python3.13/site-packages/torch/__init__.py:2126
#    2119 from torch._compile import _disable_dynamo  # usort: skip
#    2121 ################################################################################
#    2122 # Import interface functions defined in Python
#    2123 ################################################################################
#    2124
#    2125 # needs to be after the above ATen bindings so we can overwrite from Python side
# -> 2126 from torch import _VF as _VF, functional as functional  # usort: skip
#    2127 from torch.functional import *  # usort: skip # noqa: F403
#    2129 ################################################################################
# ...

# %% [markdown]
# ### 1. Load pretrained model

# %%
pretrained_model = base_Model(configs).to(device)
ckp = torch.load("experiments_logs/Exp1/run1/self_supervised_seed_0/saved_models/ckp_last.pt",
                 map_location=device)
pretrained_model.load_state_dict(ckp["model_state_dict"])

# Freeze weights
for p in pretrained_model.parameters():
    p.requires_grad = False
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 pretrained_model = base_Model(configs).to(device)
#       2 ckp = torch.load("experiments_logs/Exp1/run1/self_supervised_seed_0/saved_models/ckp_last.pt",
#       3                  map_location=device)
#       4 pretrained_model.load_state_dict(ckp["model_state_dict"])
#
# NameError: name 'base_Model' is not defined
